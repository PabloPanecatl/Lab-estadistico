# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_excel(r"C:\Users\pablo\OneDrive - ITESO\Semestre 5\Laboratorio de aprendizaje estadístico\Boston Housing Dataset 1978.xlsx")

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT       0
# MEDV       54
# dtype: int64

# %%
df2 = df.dropna()
df2.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
y = df2['MEDV'].values
X_crim = df2['CRIM'].values.reshape(-1, 1)
X_zn = df2['ZN'].values.reshape(-1, 1)
X_indus = df2['INDUS'].values.reshape(-1, 1)
X_chas = df2['CHAS'].values.reshape(-1, 1)
X_nox = df2['NOX'].values.reshape(-1, 1)
X_rm = df2['RM'].values.reshape(-1, 1)
X_age = df2['AGE'].values.reshape(-1, 1)
X_dis = df2['DIS'].values.reshape(-1, 1)
X_rad = df2['RAD'].values.reshape(-1, 1)
X_tax = df2['TAX'].values.reshape(-1, 1)
X_ptratio = df2['PTRATIO'].values.reshape(-1, 1)
X_b = df2['B'].values.reshape(-1, 1)
X_lstat = df2['LSTAT'].values.reshape(-1, 1)

# %%
n = len(y)
ones = np.ones((n, 1))
Xbig = np.hstack((ones, X_crim, X_zn, X_indus, X_chas, X_nox, X_rm, X_age, X_dis, X_rad, X_tax, X_ptratio, X_b, X_lstat))

# %%
ols = sm.OLS(y, Xbig)
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     96.16
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):          2.64e-119
# Time:                        17:32:44   Log-Likelihood:                -1319.4
# No. Observations:                 452   AIC:                             2667.
# Df Residuals:                     438   BIC:                             2724.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.8664      5.477      3.810      0.000      10.102      31.631
# ...

# %%
df2 = df2.drop_duplicates()

# %%
y = df2['MEDV'].values
X_crim = df2['CRIM'].values.reshape(-1, 1)
X_zn = df2['ZN'].values.reshape(-1, 1)
X_indus = df2['INDUS'].values.reshape(-1, 1)
X_chas = df2['CHAS'].values.reshape(-1, 1)
X_nox = df2['NOX'].values.reshape(-1, 1)
X_rm = df2['RM'].values.reshape(-1, 1)
X_age = df2['AGE'].values.reshape(-1, 1)
X_dis = df2['DIS'].values.reshape(-1, 1)
X_rad = df2['RAD'].values.reshape(-1, 1)
X_tax = df2['TAX'].values.reshape(-1, 1)
X_ptratio = df2['PTRATIO'].values.reshape(-1, 1)
X_b = df2['B'].values.reshape(-1, 1)
X_lstat = df2['LSTAT'].values.reshape(-1, 1)

# %%
n = len(y)
ones = np.ones((n, 1))
Xbig = np.hstack((ones, X_crim, X_zn, X_indus, X_chas, X_nox, X_rm, X_age, X_dis, X_rad, X_tax, X_ptratio, X_b, X_lstat))
ols = sm.OLS(y, Xbig)
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     96.16
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):          2.64e-119
# Time:                        17:33:00   Log-Likelihood:                -1319.4
# No. Observations:                 452   AIC:                             2667.
# Df Residuals:                     438   BIC:                             2724.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.8664      5.477      3.810      0.000      10.102      31.631
# ...

# %%
df2.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean     1.420825   12.721239   10.304889    0.077434    0.540816    6.343538
# std      2.495894   24.326032    6.797103    0.267574    0.113816    0.666808
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.069875    0.000000    4.930000    0.000000    0.447000    5.926750
# 50%      0.191030    0.000000    8.140000    0.000000    0.519000    6.229000
# 75%      1.211460   20.000000   18.100000    0.000000    0.605000    6.635000
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean    65.557965    4.043570    7.823009  377.442478   18.247124  369.826504
# ...

# %%
X_crim = (X_crim - X_crim.min()) / (X_crim.max() - X_crim.min())
X_zn = (X_zn - X_zn.min()) / (X_zn.max() - X_zn.min())
X_indus = (X_indus - X_indus.min()) / (X_indus.max() - X_indus.min())
X_chas = (X_chas - X_chas.min()) / (X_chas.max() - X_chas.min())
X_nox = (X_nox - X_nox.min()) / (X_nox.max() - X_nox.min())
X_rm = (X_rm - X_rm.min()) / (X_rm.max() - X_rm.min())
X_age = (X_age - X_age.min()) / (X_age.max() - X_age.min())
X_dis = (X_dis - X_dis.min()) / (X_dis.max() - X_dis.min())
X_rad = (X_rad - X_rad.min()) / (X_rad.max() - X_rad.min())
X_tax = (X_tax - X_tax.min()) / (X_tax.max() - X_tax.min())
X_ptratio = (X_ptratio - X_ptratio.min()) / (X_ptratio.max() - X_ptratio.min())
X_b = (X_b - X_b.min()) / (X_b.max() - X_b.min())
X_lstat = (X_lstat - X_lstat.min()) / (X_lstat.max() - X_lstat.min())

# %%
n = len(y)
ones = np.ones((n, 1))
Xbig = np.hstack((ones, X_crim, X_zn, X_indus, X_chas, X_nox, X_rm, X_age, X_dis, X_rad, X_tax, X_ptratio, X_b, X_lstat))
ols = sm.OLS(y, Xbig)
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     96.16
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):          2.64e-119
# Time:                        17:42:29   Log-Likelihood:                -1319.4
# No. Observations:                 452   AIC:                             2667.
# Df Residuals:                     438   BIC:                             2724.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.9457      2.615      7.626      0.000      14.805      25.086
# ...
